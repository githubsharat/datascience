# %% [markdown]
# **Class**
#
# 10 Examples

# %%
1. class hello:
        print("hello")
        
2. class test:
        pass
        
3. class new:
        def __init__(self,a,b):
                self.a = a
                self.b = b
4. class name:
        a = 'Amit '
        b = 'Singh'
        def add:
            print(a+b)
            
5. class people:
      def __init__(self, name, height, age):
            self.name = name
            self.height = height
            self.age = age
            
6. class students:
      def __init__(name, roll_no, grade):
            self.name = name
            self.roll_no = roll_no
            self.grade = grade
            
7.   class new_list:
        def __init__(self,x):
            self.x = x

        def string1(self):
            c = ''
            for i in self.x:
                c = c + str(i)
            return c        
        
8.       class one:
            def__init__(self,a):
                self.a = a

        class two(one):
            def__init__(self,a,b):
                super().__init__(a)
                self.b = b
                
9.     class acc:
            name = 'John'
            _username = "test"
            __password = "123456"
   
10.    built in classes: int, float, set, list, tuple, dict

# %% [markdown]
# **Object**
#
# 10 Examples

# %%
class level:
    def __init__(self,a):
        self.a = a
    def print1(self):
        print(self.a)
        

object7 = level(2==2)

object8 = level(None)

object9 = level(2+3j)
        
object1 = level('b')

object2 = level(2)

object10 = level(3.0)

object3 = level([1,2,3])

object4 = level({2,3,3})

object5 = level({'a':'2'})

object6 = level('Test')

# %% [markdown]
# **Public, Protected, Private Variables**

# %%
public variable

a1 = 1
a2 = 2
a3 = 3
a4 = 4
a5 = 5
a6 = 6
a7 = 7
a8 = 8
a9 = 9
a10 = 10

protected variable

_a1 = 1
_a2 = 2
_a3 = 3
_a4 = 4
_a5 = 5
_a6 = 6
_a7 = 7
_a8 = 8
_a9 = 9
_a10 = 10

private variable

__a1 = 1
__a2 = 2
__a3 = 3
__a4 = 4
__a5 = 5
__a6 = 6
__a7 = 7
__a8 = 8
__a9 = 9
__a10 = 10

# %% [markdown]
# **Packages - 10 examples**
#
# requests
# urllib3
# BeautifulSoup
# pandas
# numpy
# matplotlib
# seaborn
# scikit-learn
# scipy
# NLTK
#
#
#
# **Modules - 10 examples**
#
# math
# pip
# functools
# datetime
# logging
# re
# urllib
# email
# glob
# importlib

# %% [markdown]
# **Constructor**

# %%
def __init__(self):
    pass

def __init__(test):
    pass

def __init__(self,a):
    self.a = a
    
def __init__(test,a):
    test.a = a
    
def __init__(test,a,b):
    self.a = a
    self.b = b
    
def __init__(self,alpha):
    self.alpha = alpha
    
def __init__(self):
    print("Hello")
    
def __init__(test):
    print("Hello")
    
def__init__(self,string1):
    self.string1 = string1
    print(string1)
    
def__init__(hello,string1):
    hello.string1 = string1
    print(string1)

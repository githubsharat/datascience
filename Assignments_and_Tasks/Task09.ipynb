# %% [markdown]
# ## Task 1 - Fitbit Dataset

# %% [markdown]
# 1. Read this dataset in pandas , mysql and mongodb
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
# hint - use csvkit library to automate this task and to load a data in bulk in you mysql
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
# 4 . Find out in this data that how many unique id's we have
# 5 . which id is one of the active id that you have in whole dataset
# 6 . how many of them have not logged there activity find out in terms of number of ids
# 7 . Find out who is the laziest person id that we have in dataset
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset
# 9. how many person are not a regular person with respect to activity try to find out those
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
# 11 . who is the 5th most laziest person avilable in dataset find it out
# 12 . what is a totla acumulative calories burn for a person find out
#
# submit your git link for the same
# sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %%
import mysql.connector as conn
import pymysql
import pymongo
import pandas as pd

# %% [markdown]
# ### Read the csv data as pandas dataframe

# %%
df = pd.read_csv("FitBit data.csv")

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# ### Store the csv data in MySQL

# %%
mydb = conn.connect(host = "localhost" , user ="root" , passwd = "root" )
cursor = mydb.cursor()

s = "create database if not exists db2"
cursor.execute(s)
s = "use db2"
cursor.execute(s)

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="root",
                               db="db2"))

# %%
df.to_sql('fitbit_table', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 457

# %% [markdown]
# ### Store the csv data in MongoDB

# %%
client = pymongo.MongoClient("mongodb+srv://root:root@cluster0.wwjqu.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.wwjqu.mongodb.net:27017', 'cluster0-shard-00-02.wwjqu.mongodb.net:27017', 'cluster0-shard-00-01.wwjqu.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-fsdewf-shard-0', tls=True), 'test')

# %%
database = client['db3'] #creates database (db3)

# %%
collection = database["coll"]  # creates collection (coll)

# %%
collection.insert_many(df.to_dict('records')) #converts dataframe to dictionary and stores it in the collection

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# ### 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %%
df['Date_Formatted'] = df['ActivityDate'].apply(lambda x: pd.Timestamp(x))

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s = "use db2"
cursor.execute(s)

s = "SELECT STR_TO_DATE(ActivityDate,'%m/%d/%Y') as DateFormatted FROM fitbit_table"
cursor.execute(s)

# %% [markdown]
# ### 4 . Find out in this data that how many unique id's we have

# %%
df['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
print(f'There are {len(df.Id.unique())} unique Ids in the dataset')
# Out:
# There are 35 unique Ids in the dataset

# %% [markdown]
# ### 5 . which id is one of the active id that you have in whole dataset

# %%
#Top 5 Active Ids in the dataset

df['Id'].value_counts().head(5)
# Out:
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# Name: Id, dtype: int64

# %% [markdown]
# ### 6 . how many of them have not logged there activity find out in terms of number of ids

# %%
bool = df['TotalSteps'] == 0
len(df[bool]['Id'].unique())
# Out:
# 14

# %% [markdown]
# ### 7 . Find out who is the laziest person id that we have in dataset

# %%
bool = df['Calories'] == 0

df[bool]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 134  2873212765    4/12/2016           0            0.0              0.0
# 240  4319703577     4/9/2016           0            0.0              0.0
# 290  4702921684    4/12/2016           0            0.0              0.0
# 323  6117666160    4/10/2016           0            0.0              0.0
# 412  8253242879    4/12/2016           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 134                       0.0                 0.0                       0.0
# 240                       0.0                 0.0                       0.0
# 290                       0.0                 0.0                       0.0
# 323                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
#
# ...

# %% [markdown]
# ### 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
#Let's assume 2000 calories need to be burnt to be healthy

bool = df['Calories'] > 2000

df[bool]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 10   1503960366     4/4/2016       14557       9.800000         9.800000
# 11   1503960366     4/5/2016       14844       9.730000         9.730000
# 38   1644430081     4/1/2016        4636       3.410000         3.410000
# 39   1644430081     4/2/2016       20237      14.710000        14.710000
# ..          ...          ...         ...            ...              ...
# 451  8877689391     4/7/2016       10910       8.420000         8.420000
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# ### 9. how many person are not a regular person

# %%
#Top 5 Ids who are not regular
# first three Ids appeared just 1.7 % times, next two Ids appeared 1.9% times.

df['Id'].value_counts(normalize=True, ascending=True).nsmallest(5)
# Out:
# 8583815059    0.017505
# 2891001357    0.017505
# 4388161847    0.017505
# 6775888955    0.019694
# 6391747486    0.019694
# Name: Id, dtype: float64

# %% [markdown]
# ### 10 . who is the third most active person in this dataset find out those in pandas and in sql both .

# %% [markdown]
# #### Using Pandas

# %%
df['Id'].value_counts().head(3)

#Third most active person is with ID:1503960366 who appeared 19 times
# Out:
# 4057192912    32
# 4020332650    32
# 1503960366    19
# Name: Id, dtype: int64

# %% [markdown]
# #### Using MySQL

# %%
mydb = conn.connect(host = "localhost" , user ="root" , passwd = "root" )
cursor = mydb.cursor()

s = 'use db2'
cursor.execute(s)

s = 'select Id, count(*) from fitbit_table group by (Id) order by count(*) desc limit 3'
cursor.execute(s)

for i in cursor.fetchall():
    print(i)

#Third most active person is with ID:1503960366 who appeared 19 times
# Out:
# (4057192912, 32)
# (4020332650, 32)
# (1624580081, 19)

# %% [markdown]
# ### 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
df.sort_values('Calories').iloc[4]
# Out:
# Id                                   4319703577
# ActivityDate                           4/9/2016
# TotalSteps                                    0
# TotalDistance                               0.0
# TrackerDistance                             0.0
# LoggedActivitiesDistance                    0.0
# VeryActiveDistance                          0.0
# ModeratelyActiveDistance                    0.0
# LightActiveDistance                         0.0
# SedentaryActiveDistance                     0.0
# VeryActiveMinutes                             0
# FairlyActiveMinutes                           0
# LightlyActiveMinutes                          0
# SedentaryMinutes                           1440
# Calories                                      0
# Date_Formatted              2016-04-09 00:00:00
# Name: 240, dtype: object

# %% [markdown]
# ### 12 . what is a total acumulative calories burn for a person find out

# %%
df1 = df.groupby('Id')['Calories'].sum()

# %%
df1
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64

# %% [markdown]
# ## Task 2 - Superstore_USA

# %% [markdown]
# 1 . load this data in sql and in pandas with a relation in sql
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3 . Find out how return that we ahve recived and with a product id
# 4 . try  to join order and return data both in sql and pandas
# 5 . Try to find out how many unique customer that we have
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10 . Try to find out  a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11 . Gorup by region and find out which region is more profitable
# 12 . Try to find out overalll in which country we are giving more didscount
# 13 . Give me a list of unique postal code
# 14 . which customer segement is more profitalble find it out .
# 15 . try to find out the 10th most loss making product catagory .
# 16 . Try to find out 10 top  product with highest margins

# %%
df_orders = pd.read_excel("Superstore_USA.xlsx", sheet_name = 'Orders')
df_returns = pd.read_excel("Superstore_USA.xlsx", sheet_name = 'Returns')
df_users = pd.read_excel("Superstore_USA.xlsx", sheet_name = 'Users')

# %%
df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df_returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
df_users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ### Store the csv data in MySQL

# %%
mydb = conn.connect(host = "localhost" , user ="root" , passwd = "root" )
cursor = mydb.cursor()

s = "create database if not exists db3"
cursor.execute(s)
s = "use db3"
cursor.execute(s)

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="root",
                               db="db3"))

# %%
df_orders.to_sql('orders_table', con = engine, if_exists = 'append', chunksize = 1000)
df_returns.to_sql('returns_table', con = engine, if_exists = 'append', chunksize = 1000)
df_users.to_sql('users_table', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 4

# %% [markdown]
# ### 3 . Find out how many return that we have received and with a product id (order id)

# %%
df_returns['Order ID'].value_counts()
# Out:
# 65        1
# 152504    1
# 153144    1
# 153081    1
# 153016    1
#          ..
# 59776     1
# 59683     1
# 59680     1
# 59652     1
# 182906    1
# Name: Order ID, Length: 1634, dtype: int64

# %% [markdown]
# ### 4 . try  to join order and return data both in sql and pandas

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df_returns.columns
# Out:
# Index(['Order ID', 'Status'], dtype='object')

# %% [markdown]
# ### Pandas

# %%
df_merged = pd.merge(df_orders, df_returns  , how = 'inner' , on = 'Order ID')
df_merged.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
# 3    5055           High      0.02        3.28           5.00          117
# 4    5573            Low      0.02       11.97           5.81          272
#
#           Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4         Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
#
# ...

# %% [markdown]
# ### MySQL

# %%
mydb = conn.connect(host = "localhost" , user ="root" , passwd = "root" )
cursor = mydb.cursor()

s = "use db3"
cursor.execute(s)

s = 'SELECT * FROM orders_table INNER JOIN returns_table ON orders_table.`Order ID` = returns_table.`Order ID`'
cursor.execute(s)

# %% [markdown]
# ### 5 . Try to find out how many unique customer that we have

# %%
len(df_orders['Customer ID'].unique())
# Out:
# 2703

# %% [markdown]
# ### 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df_users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ### 7 . find out how many different different shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
df_orders['Ship Mode'].value_counts(normalize=True)*100    # Results will be in %
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %% [markdown]
# ### 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df_orders['Difference'] = df_orders['Ship Date'] - df_orders['Order Date'] 

df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %% [markdown]
# ### 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
df_orders["Difference"] = df_orders["Difference"].astype(str)

df_orders["Difference_Days"] = df_orders["Difference"].str.split(" ", expand = True).iloc[:,0]

bool = df_orders["Difference_Days"].astype(int) > 10

df_orders[bool]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %% [markdown]
# ### 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
df_merge_1 = pd.merge(df_orders, df_returns  , how = 'outer' , on = 'Order ID')

df_merge_all = pd.merge(df_merge_1, df_users  , how = 'outer' , on = 'Region')

# %%
df_merge_all["Difference_Days"].isna().value_counts(normalize=True)*100  # Check NaN and non-NaN values in %. 14% are Nan
# Out:
# False    85.6987
# True     14.3013
# Name: Difference_Days, dtype: float64

# %%
df_merge1 = df_merge_all[df_merge_all['Difference_Days'].notna()] # Let's only consider non NaN values

bool1 = df_merge1["Difference_Days"].astype(int) > 15

bool2 = df_merge1["Status"] == "Returned"

df1 = df_merge1[bool1 & bool2]
df1

# for shipment duration of > 15 days, no data was found.
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Difference, Difference_Days, Status, Manager]
# Index: []
#
# [0 rows x 28 columns]

# %%
# However, for shipment duration of > 4 days

df_merge1 = df_merge_all[df_merge_all['Difference_Days'].notna()] # Let's only consider non NaN values

bool1 = df_merge1["Difference_Days"].astype(int) > 4

bool2 = df_merge1["Status"] == "Returned"

df1 = df_merge1[bool1 & bool2]

df1["Manager"]
# Out:
# 3589    William
# 3814    William
# 4873    William
# 4874    William
# 6053       Erin
# 6054       Erin
# 6055       Erin
# 6056       Erin
# Name: Manager, dtype: object

# %% [markdown]
# ### 11 . Gorup by region and find out which region is more profitable

# %%
import numpy as np

df_merge_all['Profit'] = df_merge_all['Profit'].replace(np.nan, 0)  # replace NaN with 0 in profit column

df_merge_all.groupby('Region')['Profit'].sum()   # Central region is most profitable
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
df_merge_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10999 entries, 0 to 10998
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   float64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   float64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
# ...

# %% [markdown]
# ### 12 . Try to find out overalll in which country we are giving more discount
#
# Considering the question as: In which state we are giving more discount because, the excel file only has one country data. That is, USA.

# %%
df_merge_all['Discount'] = df_merge_all['Discount'].replace(np.nan, 0)  # replace NaN with 0 in discount column

df_merge_all.groupby('State or Province')['Discount'].sum().sort_values(ascending=False).head(1)
# Out:
# State or Province
# California    52.28
# Name: Discount, dtype: float64

# %% [markdown]
# ### 13 . Give me a list of unique postal code

# %%
lst = df_merge_all['Postal Code'].unique().astype(int).tolist()
lst
# Out:
# [60101,
#  55372,
#  68005,
#  62002,
#  75019,
#  62701,
#  60107,
#  60477,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  76903,
#  78207,
#  60004,
#  76148,
#  60452,
#  76131,
#  76240,
#  78415,
#  60505,
#  66212,
#  48138,
#  74006,
#  75217,
#  77536,
#  63114,
#  60453,
#  60302,
#  60462,
#  50208,
#  66203,
#  55423,
#  55901,
#  55113,
#  78589,
#  66614,
#  67212,
#  60130,
#  60510,
#  48234,
#  62223,
#  61008,
#  61701,
#  60440,
#  68025,
#  68801,
#  68847,
#  68502,
#  48509,
#  63105,
#  78666,
#  68104,
#  61801,
#  68701,
#  56301,
#  60543,
#  55416,
#  46041,
#  76067,
#  64064,
#  63043,
#  60061,
#  78155,
#  75090,
#  68046,
#  60067,
#  60068,
#  60087,
#  60185,
#  75081,
#  60187,
#  60090,
#  61554,
#  61604,
#  60091,
#  60517,
#  46016,
#  47401,
#  46032,
#  47201,
#  48195,
#  55106,
#  55378,
#  60544,
#  62301,
#  55379,
#  60089,
#  77373,
#  75203,
#  52501,
#  64133,
#  63301,
#  64506,
# ...

# %% [markdown]
# ### 14 . which customer segement is more profitalble find it out .

# %%
df_merge_all.groupby('Customer Segment')['Profit'].sum().sort_values(ascending=False)
# Out:
# Customer Segment
# Corporate         505538.627783
# Small Business    316474.592482
# Home Office       283869.553814
# Consumer          206559.625348
# Name: Profit, dtype: float64

# %%
df_merge_all.groupby('Customer Segment')['Profit'].sum().sort_values(ascending=False).head(1)  # most profitable
# Out:
# Customer Segment
# Corporate    505538.627783
# Name: Profit, dtype: float64

# %% [markdown]
# ### 15 . try to find out the 10th most loss making product catagory .

# %%
df_merge_all.groupby('Product Category')['Profit'].sum().sort_values()


#There are only 3 types in Product Category Column. least profit / Most loss making category is Furniture
# Out:
# Product Category
# Furniture          177354.298188
# Office Supplies    451990.216492
# Technology         683097.884748
# Name: Profit, dtype: float64

# %%
loss_10 = df_merge_all.groupby('Product Name')['Profit'].sum().sort_values().head(10) # Top 10 Most loss making products
loss_10
# Out:
# Product Name
# Okidata Pacemark 4410N Wide Format Dot Matrix Printer                            -39743.177832
# Polycom ViewStation™ ISDN Videoconferencing Unit                                 -36446.423528
# Epson DFX-8500 Dot Matrix Printer                                                -29557.665792
# Global High-Back Leather Tilter, Burgundy                                        -23236.837560
# Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table   -14874.638164
# Hoover Portapower™ Portable Vacuum                                               -14120.392820
# Large Capacity Hanging Post Binders                                              -12442.721780
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                -11541.176706
# KI Conference Tables                                                             -10066.260905
# Eldon ClusterMat Chair Mat with Cordless Antistatic Protection                    -9543.652500
# ...

# %%
loss_10 = loss_10.to_frame()

loss_10.iloc[9]                #10th most lost making product
# Out:
# Profit   -9543.6525
# Name: Eldon ClusterMat Chair Mat with Cordless Antistatic Protection, dtype: float64

# %% [markdown]
# ### 16 . Try to find out 10 top  product with highest margins

# %%
df_merge_all.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Global Troy™ Executive Leather Low-Back Tilter                                 79509.392200
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    35909.525185
# GBC DocuBind 200 Manual Binding Machine                                        33892.328503
# Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers                    33721.100200
# Hewlett Packard LaserJet 3310 Copier                                           33712.303300
# Canon PC940 Copier                                                             28307.563490
# GBC DocuBind TL300 Electric Binding System                                     25033.896400
# Hewlett-Packard Deskjet 1220Cse Color Inkjet Printer                           24782.747900
# Ibico Hi-Tech Manual Binding System                                            23080.569840
# Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators                             23076.410700
# Name: Profit, dtype: float64
